# %%
#in the name of god

# %%
import pandas as pd
import pickle

# %%
df=pd.read_csv('Data\\DF.csv').set_index("timestamp")
with open("Data\\Model_param.txt", "rb") as fp:
        Model_param = pickle.load(fp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-224563739294> in <module>
#       1 df=pd.read_csv('Data\\DF.csv').set_index("timestamp")
# ----> 2 with open("Model_param.txt", "rb") as fp:
#       3         Model_param = pickle.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Model_param.txt'

# %%
df
# Out:
#                             trip_id   latitude  longitude  altitude    gyr_x  \
# timestamp
# 2017-01-19 16:19:04.742113        3  4703.7815  1527.4713     359.9  1.11304
# 2017-01-19 16:19:05.741890        3  4703.7815  1527.4714     359.9  1.11304
# 2017-01-19 16:19:06.738842        3  4703.7816  1527.4716     360.3  1.11304
# 2017-01-19 16:19:07.744001        3  4703.7814  1527.4718     360.5  1.25217
# 2017-01-19 16:19:08.746266        3  4703.7814  1527.4720     360.8  1.32174
# ...                             ...        ...        ...       ...      ...
# 2017-01-30 06:58:36.495375       35  4703.5440  1527.7215     358.7  3.33913
# 2017-01-30 06:58:36.692035       35  4703.5440  1527.7215     358.7  3.40870
# 2017-01-30 06:58:36.892624       35  4703.5440  1527.7215     358.7  3.20000
# 2017-01-30 06:58:37.093979       35  4703.5440  1527.7215     358.7  3.20000
# 2017-01-30 06:58:37.297740       35  4703.5440  1527.7215     358.7  2.92174
#
# ...
